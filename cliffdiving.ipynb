# %% [markdown]
# # Cliff Diving Web Scraping
#
# This code scrapes cliff diving spots from the [Ultimate Wild Trip](https://www.ultimatewildtrip.com/en/cliff-diving-in-australia/) website.
#
# The Google Maps Geolocation API is then used to get the latitude and longitude of the spot so it can be plotted on the map. Geopy is a convenient python wrapper for the API.

# %%
import requests, bs4
import pandas as pd
from urllib.parse import urljoin
from geopy.geocoders import GoogleV3
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# To use the Google Maps Geolocation service, you need an API key. You can sign up for free [here](https://console.cloud.google.com/home) then input the key below.

# %%
api_key = input()

# %%
geolocator = GoogleV3(api_key=api_key,
                      domain='maps.googleapis.com',
                      user_agent="get-indoor-rock-climbing-coord")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=0.3)

# %%
def get_soup(url):
    res = requests.get(url)
    res.raise_for_status()
    return bs4.BeautifulSoup(res.text, "lxml")

# %% [markdown]
# The function **get_soup** is used to get the raw html. All of the diving spots are in a *div* tag with the name *et_pb_blurb_description* as highlighted below:
#
#
# ![img](CliffDiving.png)

# %%
soup = get_soup('https://www.ultimatewildtrip.com/en/cliff-diving-in-australia/')
spots = soup.find_all("div", {"class": "et_pb_blurb_description"})

# %% [markdown]
# The place, location and height can then be extracted using a combination of finding elements, splitting and combining into an f-string.

# %%
df = pd.DataFrame(columns=['name', 'Sport', 'routes', 'url', 'lat', 'long'])

for i, spot in enumerate(spots):
    df.loc[i, 'url'] = spot.find('iframe')['src']
    df.loc[i, 'location'] = f"{spot.find_all('p')[1].text.split(':')[1]} {spot.find_all('p')[2].text.split(':')[1]}"
    try:
        df.loc[i, 'routes'] = f"{spot.find_all('p')[3].text.split(':')[1].strip()}"
    except IndexError:
        continue
df.Sport = "Cliff Diving"

# %% [markdown]
# Finally, the geocoding is applied to get the latitude and longitude.

# %%
df['geo'] = df.location.apply(geocode)
df['lat'] = df.geo.apply(lambda x: x.latitude if x else pd.NA)
df['long'] = df.geo.apply(lambda x: x.longitude if x else pd.NA)
df.name = df.location.apply(lambda x: x.split(',')[0])
df
# Out:
#                                          name         Sport    routes  \
# 0      Cliffs in the Ord River  The Kimberley  Cliff Diving  > 12-28m
# 1                 Jervis Bay  New South Wales  Cliff Diving    >6-20m
# 2                       Jerusalem Bay  Sydney  Cliff Diving     > 10m
# 3    Blairgowrie jumping rock  Bridgwater Bay  Cliff Diving      > 7m
# 4                            Tasmania  >5-15m  Cliff Diving       NaN
# 5                                      Darwin  Cliff Diving       NaN
# 6                Watson Bay-Camp Cove  Sydney  Cliff Diving       >6m
# 7                     New South Wales  >6-15m  Cliff Diving       NaN
# 8                                     Tahmoor  Cliff Diving       NaN
# 9                                Mount Martha  Cliff Diving       NaN
# 10                                      Perth  Cliff Diving       NaN
# 11                   Litchfield National Park  Cliff Diving       NaN
# 12                           Wattamolla Beach  Cliff Diving       >9m
# 13                     New South Wales  > 15m  Cliff Diving       NaN
# 14                            North Melbourne  Cliff Diving       NaN
# 15                   South Australia  > 5-20m  Cliff Diving       NaN
# 16            Kuranda Falls  North Queensland  Cliff Diving     > 27m
#
#                                                   url        lat        long  \
# 0   https://www.youtube-nocookie.com/embed/IMCyRdR... -17.437711  127.999223
# 1   https://www.youtube-nocookie.com/embed/tTC18X3... -35.048080  150.744677
# 2   https://www.youtube-nocookie.com/embed/vJh_N8M... -33.589133  151.186589
# 3   https://www.youtube-nocookie.com/embed/Qw0D5Ds... -38.371971  144.766982
# 4   https://www.youtube-nocookie.com/embed/M9yX335... -42.040906  146.808732
# 5   https://www.youtube-nocookie.com/embed/3BTFtyW... -12.463733  130.844445
# 6   https://www.youtube-nocookie.com/embed/TFAf3rk... -33.839307  151.278377
# 7   https://www.youtube-nocookie.com/embed/yNefNOT... -31.253218  146.921099
# 8   https://www.youtube-nocookie.com/embed/f3agMEx... -34.228844  150.590756
# 9   https://www.youtube-nocookie.com/embed/QQOZ9F8... -38.267000  145.018000
# 10  https://www.youtube-nocookie.com/embed/lhnDShH... -31.952312  115.861309
# 11  https://www.youtube-nocookie.com/embed/j24R5If... -13.293538  130.846388
# 12  https://www.youtube-nocookie.com/embed/0A3O4Ar... -34.137419  151.117469
# 13  https://www.youtube-nocookie.com/embed/etZ0duL... -31.253218  146.921099
# 14  https://www.youtube-nocookie.com/embed/I0RGaLH... -37.799167  144.946667
# 15  https://www.youtube-nocookie.com/embed/N3s1b3k... -30.000232  136.209155
# 16  https://www.youtube-nocookie.com/embed/HBEzlbB... -16.833133  145.643005
#
#                                              location  \
# 0          Cliffs in the Ord River  The Kimberley, WA
# 1                         Jervis Bay  New South Wales
# 2                          Jerusalem Bay  Sydney, NSW
# 3    Blairgowrie jumping rock  Bridgwater Bay, Vic...
# 4                                    Tasmania  >5-15m
# 5                                  Darwin, NT  >5-18m
# 6                   Watson Bay-Camp Cove  Sydney, NSW
# 7                             New South Wales  >6-15m
# 8                                Tahmoor, NSW  >6-14m
# 9                     Mount Martha, Melbourne  >5.50m
# 10                                     Perth, WA  >7m
# 11           Litchfield National Park, Darwin  >5-12m
# 12     Wattamolla Beach,  Royal National Park, Sydney
# 13                             New South Wales  > 15m
# 14                North Melbourne, Victoria  > 10-20m
# 15                           South Australia  > 5-20m
# 16                    Kuranda Falls  North Queensland
#
#                                                   geo
# 0   (Bungle Bungle Caravan Park & Tour Company, Gr...
# 1   (Jervis Bay, New South Wales, Australia, (-35....
# 2   (Jerusalem Bay Trail, New South Wales, Austral...
# 3   (Bridgewater Bay, Stairs, Blairgowrie VIC 3942...
# 4   (Tasmania, Australia, (-42.0409059, 146.8087323))
# 5   (Darwin NT, Australia, (-12.4637333, 130.84444...
# 6   (Camp Cove, New South Wales, Australia, (-33.8...
# 7   (New South Wales, Australia, (-31.2532183, 146...
# 8   (Tahmoor NSW 2573, Australia, (-34.2288439, 15...
# 9   (Mount Martha VIC 3934, Australia, (-38.267, 1...
# 10   (Perth WA, Australia, (-31.9523123, 115.861309))
# 11  (Litchfield National Park, Litchfield Park Rd,...
# 12  (Wattamolla Beach, Royal National Park NSW 223...
# 13  (New South Wales, Australia, (-31.2532183, 146...
# 14  (North Melbourne VIC 3051, Australia, (-37.799...
# 15  (South Australia, Australia, (-30.0002315, 136...
# 16  (Centenary Park, Coondoo St, Kuranda QLD 4881,...

# %%
df.drop(['geo', 'location'], axis=1).to_excel('_data/cliffdiving.xlsx', index=None)
